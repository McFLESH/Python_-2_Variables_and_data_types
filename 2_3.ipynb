# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_-2_Variables_and_data_types/blob/main/2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Напишите программу, которая принимает числа и выводит сумму их значений. На вход подаются значения через пробел.

Stroka = input()
Spisok1 = Stroka.split()
Spisok2 = map(int, Spisok1)
print(sum(Spisok2))
