# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_-2_Variables_and_data_types/blob/main/2_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Вам даны готовые строки с названиями курсов, на которые записались три студента из разных факультетов,
# и множество обязательных курсов, которые должен пройти каждый студент.
# Необходимо выяснить, какие из выбранных курсов хоть и являются необязательными, но все равно были выбраны студентами.

# Строки с выбранными курсами:

# selected_courses_1 = "ИТ-консалтинг, Экономика, Маркетинг, Философия, История, Python"
# selected_courses_2 = "Философия, Физика, Python, История, Маркетинг"
# selected_courses_3 = "История, Python, Кибербезопасность, Математика, Философия, Экономика, ИТ-консалтинг, Маркетинг"
# Множество обязательных курсов:

# mandatory_courses = {"Философия", "История", "Экономика"}

#Преобразование строк в множества
selected_courses_1 = set(selected_courses_1.split(', '))
selected_courses_2 = set(selected_courses_2.split(', '))
selected_courses_3 = set(selected_courses_3.split(', '))

#Нахождение необязательных предметов путем вычитания множеств
unmandatory_courses1 = selected_courses_1.difference(mandatory_courses)
unmandatory_courses2 = selected_courses_2.difference(mandatory_courses)
unmandatory_courses3 = selected_courses_3.difference(mandatory_courses)

#Объединение результатов
unmandatory_courses = unmandatory_courses1.union(unmandatory_courses2, unmandatory_courses3)
print(unmandatory_courses)
